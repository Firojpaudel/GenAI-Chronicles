# %% [markdown]
# ### LangGraph Components:

# %% [markdown]
# ```mermaid
# flowchart TD
#   %% Core Platform
#   Server[LangGraph Server]
#   Studio[LangGraph Studio]
#   CLI[LangGraph CLI]
#   SDK[LangGraph SDK]
#   ControlPlane[Control Plane]
#   DataPlane[Data Plane]
#
#   %% Application Components
#   Graphs[Graphs]
#   Config[API Config]
#   Dependencies[Dependencies]
#   Env[Environment Variables]
#   Assistants[Assistants]
#   Webhooks[Webhooks]
#   Cron[Cron Jobs]
#
#   %% Workflow Elements
#   State[State Management]
#   Node[Execution Nodes]
#   Edge[Edges]
#   Memory[Memory]
#   Streaming[Streaming]
#   Breakpoints[Breakpoints]
#   TimeTravel[Time Travel]
#   Persistence[Persistence]
#   Pregel[Pregel Runtime]
#   HumanLoop[Human Intervention]
#
#   %% Multi-Agent System
#   Supervisor[Supervisor Agent]
#   Agent1[Specialist Agent 1]
#   Agent2[Specialist Agent 2]
#   Team[Agent Team]
#
#   %% Integrations
#   RAG[RAG System]
#   LangSmith[LangSmith]
#
#   %% Connections
#   Server---Studio
#   Server---CLI
#   Server---SDK
#   Server---ControlPlane
#   Server---DataPlane
#   ControlPlane---DataPlane
#
#   Graphs---Server
#   Graphs-->Node
#   Node-->Edge
#   Node-->State
#   State-->Memory
#   State-->Streaming
#   State-->Breakpoints
#   State-->TimeTravel
#   State-->Persistence
#   Pregel-->Node
#   HumanLoop-->Node
#
#   Node-->Supervisor
#   Supervisor-->Agent1
#   Supervisor-->Agent2
#   Supervisor-->Team
#   Team-->Agent1
#   Team-->Agent2
#
#   Node-.->RAG
#   Node-.->LangSmith
#
#   Graphs-->Config
#   Graphs-->Dependencies
#   Graphs-->Env
#   Graphs-->Assistants
#   Graphs-->Webhooks
#   Graphs-->Cron
# ```

# %% [markdown]
# ### 1. State:
#
# It is a central concept in LangGraph. It represents all the information that flows through  the application

# %%
from typing_extensions import TypedDict

class State(TypedDict):
    graph_state: str

# %% [markdown]
# The state is userdefined.
